# %%
r = lambda a : a + 25
print(r(10))
r = lambda x : x
# Out:
# 35

# %%
nums = (1, 2, 3, 4, 5, 6, 7) 
print("mindsace: ", nums)
result = map(lambda x: x + x + x, nums) 
print("\nTriple of said list numbers:")
print(list(result))
# Out:
# mindsace:  (1, 2, 3, 4, 5, 6, 7)
#
# Triple of said list numbers:
# [3, 6, 9, 12, 15, 18, 21]

# %%
def square_num(n):
  return n * n
nums = [4, 5, 2, 9]
print("mindspace: ",nums)
result = map(square_num, nums)
print("Square the elements of the said list using map():")
print(list(result))
# Out:
# mindspace:  [4, 5, 2, 9]
# Square the elements of the said list using map():
# [16, 25, 4, 81]
